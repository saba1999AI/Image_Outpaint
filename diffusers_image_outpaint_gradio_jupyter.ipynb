# %%
# %cd /content
# !git clone -b dev https://github.com/camenduru/diffusers-image-outpaint-hf
# %cd /content/diffusers-image-outpaint-hf

# !pip install gradio==4.42.0 gradio-imageslider transformers accelerate diffusers fastapi==0.112.4

# !python app.py
# Out:
# /content
# Cloning into 'diffusers-image-outpaint-hf'...
# remote: Enumerating objects: 140, done.
# remote: Counting objects: 100% (140/140), done.
# remote: Compressing objects: 100% (70/70), done.
# remote: Total 140 (delta 76), reused 128 (delta 67), pack-reused 0 (from 0)
# Receiving objects: 100% (140/140), 538.09 KiB | 19.22 MiB/s, done.
# Resolving deltas: 100% (76/76), done.
# /content/diffusers-image-outpaint-hf
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 109.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.9/93.9 kB 10.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.7/318.7 kB 30.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.5/101.5 kB 11.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 104.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 122.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 7.8 MB/s eta 0:00:00
# ...
